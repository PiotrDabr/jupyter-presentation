# %%
import numpy as np
from ipywidgets import interact
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def handle_interact(param):
    x = np.linspace(0, 10, 1000)
    y = np.sin(x * param)
    plt.plot(x, y)

# %%
interact(handle_interact, param=10)
# Out:
# <function __main__.handle_interact>
